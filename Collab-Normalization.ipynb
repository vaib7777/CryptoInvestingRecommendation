# %%
! pip install PyMySQL
# Out:
# ...
#      |████████████████████████████████| 51kB 2.0MB/s
# ...

# %%
import pandas as pd
import numpy as np

# %%
db_connection_str = 'mysql+pymysql://myuser:mypass@34.202.176.76/adm_landing'
db_connection = create_engine(db_connection_str)
df_final = pd.read_sql('SELECT * FROM crypto_stage_data', con=db_connection)

# %%
df_final.head()
# Out:
#    cmc_id      name symbol  ...  volatility  git_commits  twitter_followers
# 0    2882    0Chain    ZCN  ...    0.273591            0            26324.0
# 1    1896        0x    ZRX  ...    0.196767         4920             4505.0
# 2    3588  Absolute    ABS  ...    0.280824            0              390.0
# 3    2299      aelf    ELF  ...    0.346416         6958               33.0
# 4    2058   AirSwap    AST  ...    0.350290            2            32003.0
#
# [5 rows x 9 columns]

# %%
df_normalize = df_final[['market_cap','volume_7d','volatility','git_commits','twitter_followers']]

# %%
df_normalize
# Out:
#       market_cap     volume_7d  volatility  git_commits  twitter_followers
# 0        1959089  1.790411e+04    0.273591            0            26324.0
# 1      121166310  1.648577e+08    0.196767         4920             4505.0
# 2          30964  1.107982e+04    0.280824            0              390.0
# 3       36903319  5.042576e+07    0.346416         6958               33.0
# 4        3464893  1.483493e+07    0.350290            2            32003.0
# 5         469786  0.000000e+00    0.269270           24                1.0
# 6          71173  1.986009e+03    0.209085            0                0.0
# 7       92806485  5.547468e+07    0.197973            2             7982.0
# 8         664756  1.096676e+05    0.118728           39             1530.0
# 9       19792848  7.299519e+06    0.326087          448            78954.0
# 10        272827  3.478051e+02    0.163395            0                NaN
# ...

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(df_normalize)
df_normalize_new = pd.DataFrame(np_scaled, columns = df_normalize.columns)
df_normalize_new
# Out:
#       market_cap     volume_7d  volatility  git_commits  twitter_followers
# 0   1.300123e-05  1.734099e-07    0.159154     0.000000       1.022755e-02
# 1   8.041040e-04  1.596727e-03    0.114464     0.707100       1.750308e-03
# 2   2.054884e-07  1.073134e-07    0.163362     0.000000       1.515250e-04
# 3   2.449039e-04  4.883978e-04    0.201518     1.000000       1.282134e-05
# 4   2.299430e-05  1.436835e-04    0.203772     0.000287       1.243398e-02
# 5   3.117672e-06  0.000000e+00    0.156641     0.003449       3.885256e-07
# 6   4.723301e-07  1.923546e-08    0.121630     0.000000       0.000000e+00
# 7   6.158978e-04  5.372991e-04    0.115166     0.000287       3.101211e-03
# 8   4.411564e-06  1.062184e-06    0.069067     0.005605       5.944442e-04
# 9   1.313526e-04  7.069937e-05    0.189693     0.064386       3.067565e-02
# 10  1.810580e-06  3.368660e-09    0.095051     0.000000                NaN
# ...

# %%
df_rank = pd.DataFrame()

# %%
df_rank['cmc_rank'] = df_final['cmc_rank'].sort_values(ascending = True)
df_rank
# Out:
#     cmc_rank
# 12         1
# 30         2
# 68         3
# 37         6
# 62        11
# 59        14
# 58        19
# 31        20
# 44        21
# 39        22
# 69        28
# 11        32
# 64        34
# 13        39
# 1         40
# 47        43
# 7         49
# 14        51
# 23        56
# 40        71
# 65        73
# 33        83
# 70        84
# 3         89
# 66        95
# 38        96
# 45       116
# 55       133
# 9        136
# 27       157
# ..       ...
# 43       486
# 4        528
# 21       538
# 49       577
# 51       578
# 57       602
# 24       611
# 0        676
# 60       678
# 41       727
# 17       738
# 36       753
# 53       803
# 25       822
# 20       835
# 67       941
# 8        969
# 63      1013
# 5       1063
# 28      1069
# 34      1091
# 10      1221
# 48      1268
# 56      1290
# 26      1294
# 18      1310
# 6       1541
# 2       1709
# 29      1713
# 61      2356
#
# [71 rows x 1 columns]

# %%
df_rank['local_rank'] = [i for i in range(1,len(df_rank)+1)]

# %%
df_rank.head()
# Out:
#     cmc_rank  local_rank
# 12         1           1
# 30         2           2
# 68         3           3
# 37         6           4
# 62        11           5

# %%
df_rank['rank_normalize'] = 1-(df_rank['local_rank']-1)*1/(len(df_rank))

# %%
df_last = pd.concat([df_normalize_new,df_rank],axis=1)

# %%
df_last.head()
# Out:
#      market_cap     volume_7d  volatility  ...  cmc_rank  local_rank  rank_normalize
# 0  1.300123e-05  1.734099e-07    0.159154  ...       676          49        0.323944
# 1  8.041040e-04  1.596727e-03    0.114464  ...        40          15        0.802817
# 2  2.054884e-07  1.073134e-07    0.163362  ...      1709          69        0.042254
# 3  2.449039e-04  4.883978e-04    0.201518  ...        89          24        0.676056
# 4  2.299430e-05  1.436835e-04    0.203772  ...       528          43        0.408451
#
# [5 rows x 8 columns]

# %%
df_last[['cmc_id','name','symbol']] = df_final[['cmc_id','name','symbol']]

# %%
df_last.head()
# Out:
#      market_cap     volume_7d  volatility  ...  cmc_id      name  symbol
# 0  1.300123e-05  1.734099e-07    0.159154  ...    2882    0Chain     ZCN
# 1  8.041040e-04  1.596727e-03    0.114464  ...    1896        0x     ZRX
# 2  2.054884e-07  1.073134e-07    0.163362  ...    3588  Absolute     ABS
# 3  2.449039e-04  4.883978e-04    0.201518  ...    2299      aelf     ELF
# 4  2.299430e-05  1.436835e-04    0.203772  ...    2058   AirSwap     AST
#
# [5 rows x 11 columns]

# %%
df_last.to_excel('final_table_latest.xlsx',encoding='utf-8')

# %%
from google.colab import files
files.download('final_table_latest.xlsx')
